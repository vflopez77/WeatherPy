# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
import citipy
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build basic URL
from config import weather_base_url
url = f"{weather_base_url}{weather_api_key}"

# %%
# Get all the city weather data
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})
                          #                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mana
# Processing Record 2 of Set 1 | north bend
# Processing Record 3 of Set 1 | ogdensburg
# Processing Record 4 of Set 1 | olinda
# Processing Record 5 of Set 1 | upata
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | zhuhai
# Processing Record 8 of Set 1 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | muros
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | katesh
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | rochester
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | barentsburg
# City barentsburg not found. Skipping...
# Processing Record 23 of Set 1 | scarborough
# Processing Record 24 of Set 1 | hambantota
# Processing Record 25 of Set 1 | tuatapere
# Processing Record 26 of Set 1 | lucapa
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | wageningen
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | itarema
# Processing Record 31 of Set 1 | kanth
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | marmande
# Processing Record 34 of Set 1 | alingsas
# Processing Record 35 of Set 1 | mabaruma
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | pisco
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | moberly
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | ippy
# Processing Record 44 of Set 1 | galiwinku
# City galiwinku not found. Skipping...
# Processing Record 45 of Set 1 | salta
# Processing Record 46 of Set 1 | maputo
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | san jeronimo
# Processing Record 49 of Set 1 | tahta
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | madang
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | catalina
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | dillon
# Processing Record 9 of Set 2 | boca do acre
# Processing Record 10 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | callaway
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | la ronge
# Processing Record 17 of Set 2 | saint-joseph
# Processing Record 18 of Set 2 | komsomolskiy
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | aromashevo
# Processing Record 21 of Set 2 | luxor
# Processing Record 22 of Set 2 | vestmanna
# Processing Record 23 of Set 2 | asau
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | mwinilunga
# Processing Record 26 of Set 2 | wenchi
# Processing Record 27 of Set 2 | quatre cocos
# Processing Record 28 of Set 2 | gat
# Processing Record 29 of Set 2 | ngukurr
# City ngukurr not found. Skipping...
# Processing Record 30 of Set 2 | college
# Processing Record 31 of Set 2 | roxana
# Processing Record 32 of Set 2 | lander
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 35 of Set 2 | banda aceh
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | narang
# Processing Record 38 of Set 2 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | ornskoldsvik
# Processing Record 41 of Set 2 | lae
# Processing Record 42 of Set 2 | abha
# Processing Record 43 of Set 2 | pisz
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | sistranda
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | jabiru
# City jabiru not found. Skipping...
# Processing Record 48 of Set 2 | abu dhabi
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | atbasar
# Processing Record 1 of Set 3 | padilla
# Processing Record 2 of Set 3 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 3 of Set 3 | daura
# Processing Record 4 of Set 3 | troitsko-pechorsk
# Processing Record 5 of Set 3 | ushtobe
# Processing Record 6 of Set 3 | stornoway
# Processing Record 7 of Set 3 | sarkand
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | tautira
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | san luis
# Processing Record 13 of Set 3 | lata
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | russell
# Processing Record 16 of Set 3 | busselton
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | mecca
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | rincon
# Processing Record 21 of Set 3 | haibowan
# City haibowan not found. Skipping...
# Processing Record 22 of Set 3 | neftekumsk
# Processing Record 23 of Set 3 | aasiaat
# Processing Record 24 of Set 3 | makakilo city
# Processing Record 25 of Set 3 | tsihombe
# City tsihombe not found. Skipping...
# Processing Record 26 of Set 3 | inza
# Processing Record 27 of Set 3 | newport
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | saurimo
# Processing Record 32 of Set 3 | tuy hoa
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | jamestown
# Processing Record 36 of Set 3 | mataura
# Processing Record 37 of Set 3 | sao filipe
# Processing Record 38 of Set 3 | havre-saint-pierre
# Processing Record 39 of Set 3 | wad rawah
# Processing Record 40 of Set 3 | bosaso
# Processing Record 41 of Set 3 | otavi
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | kvam
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | louisbourg
# City louisbourg not found. Skipping...
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | krasnoturansk
# Processing Record 50 of Set 3 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | dwarka
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | goure
# Processing Record 5 of Set 4 | genhe
# Processing Record 6 of Set 4 | kargasok
# Processing Record 7 of Set 4 | kudahuvadhoo
# Processing Record 8 of Set 4 | bambanglipuro
# Processing Record 9 of Set 4 | lichinga
# Processing Record 10 of Set 4 | auki
# Processing Record 11 of Set 4 | usinsk
# Processing Record 12 of Set 4 | puerto plata
# Processing Record 13 of Set 4 | hamilton
# Processing Record 14 of Set 4 | karachi
# Processing Record 15 of Set 4 | namatanai
# Processing Record 16 of Set 4 | cervo
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | hoghiz
# Processing Record 19 of Set 4 | lamar
# Processing Record 20 of Set 4 | boende
# Processing Record 21 of Set 4 | pangnirtung
# Processing Record 22 of Set 4 | tessalit
# Processing Record 23 of Set 4 | lagoa
# Processing Record 24 of Set 4 | westport
# Processing Record 25 of Set 4 | inuvik
# Processing Record 26 of Set 4 | bulolo
# Processing Record 27 of Set 4 | kiunga
# Processing Record 28 of Set 4 | youkounkoun
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | mocambique
# City mocambique not found. Skipping...
# Processing Record 31 of Set 4 | half moon bay
# Processing Record 32 of Set 4 | makushino
# Processing Record 33 of Set 4 | jose bonifacio
# Processing Record 34 of Set 4 | rio de janeiro
# Processing Record 35 of Set 4 | black river
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | brindisi
# Processing Record 38 of Set 4 | klyuchi
# Processing Record 39 of Set 4 | banepa
# Processing Record 40 of Set 4 | sambir
# Processing Record 41 of Set 4 | belyy yar
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | indiana
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | saint-augustin
# Processing Record 48 of Set 4 | yar-sale
# Processing Record 49 of Set 4 | mackenzie
# Processing Record 50 of Set 4 | ahipara
# Processing Record 1 of Set 5 | lakatoro
# Processing Record 2 of Set 5 | nishihara
# Processing Record 3 of Set 5 | riviere-au-renard
# Processing Record 4 of Set 5 | crestview
# Processing Record 5 of Set 5 | kerema
# Processing Record 6 of Set 5 | winnemucca
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | channel-port aux basques
# Processing Record 9 of Set 5 | tilsonburg
# City tilsonburg not found. Skipping...
# Processing Record 10 of Set 5 | strezhevoy
# Processing Record 11 of Set 5 | barrow
# Processing Record 12 of Set 5 | chicama
# Processing Record 13 of Set 5 | puerto ayora
# Processing Record 14 of Set 5 | batemans bay
# Processing Record 15 of Set 5 | katsuura
# Processing Record 16 of Set 5 | nakamura
# Processing Record 17 of Set 5 | colorado springs
# Processing Record 18 of Set 5 | blora
# Processing Record 19 of Set 5 | sri aman
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | barwala
# Processing Record 23 of Set 5 | natchez
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | amderma
# City amderma not found. Skipping...
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | mizdah
# Processing Record 28 of Set 5 | yomitan
# City yomitan not found. Skipping...
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | olafsvik
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | meyungs
# City meyungs not found. Skipping...
# Processing Record 33 of Set 5 | matagami
# Processing Record 34 of Set 5 | naze
# Processing Record 35 of Set 5 | talara
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | mahanoro
# Processing Record 38 of Set 5 | souillac
# Processing Record 39 of Set 5 | gazanjyk
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | chiang rai
# Processing Record 43 of Set 5 | tura
# Processing Record 44 of Set 5 | jalu
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | lanzhou
# Processing Record 47 of Set 5 | tazovskiy
# Processing Record 48 of Set 5 | shache
# Processing Record 49 of Set 5 | udachnyy
# Processing Record 50 of Set 5 | dakoro
# Processing Record 1 of Set 6 | new norfolk
# Processing Record 2 of Set 6 | acapulco
# Processing Record 3 of Set 6 | kaoma
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | kamyaran
# Processing Record 6 of Set 6 | harrow
# Processing Record 7 of Set 6 | poum
# Processing Record 8 of Set 6 | shatrovo
# Processing Record 9 of Set 6 | narsaq
# Processing Record 10 of Set 6 | geraldton
# Processing Record 11 of Set 6 | norman wells
# Processing Record 12 of Set 6 | yabrud
# Processing Record 13 of Set 6 | murgab
# Processing Record 14 of Set 6 | hay river
# Processing Record 15 of Set 6 | yumen
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | slave lake
# Processing Record 18 of Set 6 | yellowknife
# Processing Record 19 of Set 6 | bolungarvik
# City bolungarvik not found. Skipping...
# Processing Record 20 of Set 6 | pangoa
# Processing Record 21 of Set 6 | cabo san lucas
# Processing Record 22 of Set 6 | miri
# Processing Record 23 of Set 6 | birin
# Processing Record 24 of Set 6 | puerto escondido
# Processing Record 25 of Set 6 | magistralnyy
# Processing Record 26 of Set 6 | veraval
# Processing Record 27 of Set 6 | bisira
# Processing Record 28 of Set 6 | morondava
# Processing Record 29 of Set 6 | boguchany
# Processing Record 30 of Set 6 | winterberg
# Processing Record 31 of Set 6 | los llanos de aridane
# Processing Record 32 of Set 6 | lewistown
# Processing Record 33 of Set 6 | ostersund
# Processing Record 34 of Set 6 | lourdes
# Processing Record 35 of Set 6 | pattani
# Processing Record 36 of Set 6 | roma
# Processing Record 37 of Set 6 | craig
# Processing Record 38 of Set 6 | baghdad
# Processing Record 39 of Set 6 | sorong
# Processing Record 40 of Set 6 | verkhnetulomskiy
# Processing Record 41 of Set 6 | sitka
# Processing Record 42 of Set 6 | aberdeen
# Processing Record 43 of Set 6 | juneau
# Processing Record 44 of Set 6 | necochea
# Processing Record 45 of Set 6 | ust-kuyga
# Processing Record 46 of Set 6 | vila franca do campo
# Processing Record 47 of Set 6 | san cristobal
# Processing Record 48 of Set 6 | mount isa
# Processing Record 49 of Set 6 | ayan
# Processing Record 50 of Set 6 | faya
# Processing Record 1 of Set 7 | sao jose de ribamar
# Processing Record 2 of Set 7 | boden
# Processing Record 3 of Set 7 | mehran
# Processing Record 4 of Set 7 | awbari
# Processing Record 5 of Set 7 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 6 of Set 7 | fukue
# Processing Record 7 of Set 7 | flagstaff
# Processing Record 8 of Set 7 | klaksvik
# Processing Record 9 of Set 7 | artyk
# City artyk not found. Skipping...
# Processing Record 10 of Set 7 | samarai
# Processing Record 11 of Set 7 | takoradi
# Processing Record 12 of Set 7 | lorengau
# Processing Record 13 of Set 7 | woodward
# Processing Record 14 of Set 7 | hun
# Processing Record 15 of Set 7 | nioro
# Processing Record 16 of Set 7 | suratgarh
# Processing Record 17 of Set 7 | daru
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | zhigansk
# Processing Record 20 of Set 7 | atambua
# Processing Record 21 of Set 7 | yinchuan
# Processing Record 22 of Set 7 | longyearbyen
# Processing Record 23 of Set 7 | mount gambier
# Processing Record 24 of Set 7 | umzimvubu
# City umzimvubu not found. Skipping...
# Processing Record 25 of Set 7 | kuala terengganu
# Processing Record 26 of Set 7 | polunochnoye
# Processing Record 27 of Set 7 | comonfort
# Processing Record 28 of Set 7 | bella vista
# Processing Record 29 of Set 7 | lebanon
# Processing Record 30 of Set 7 | elizabeth city
# Processing Record 31 of Set 7 | gorom-gorom
# Processing Record 32 of Set 7 | kloulklubed
# Processing Record 33 of Set 7 | toliary
# City toliary not found. Skipping...
# Processing Record 34 of Set 7 | kjollefjord
# Processing Record 35 of Set 7 | biak
# Processing Record 36 of Set 7 | wanning
# Processing Record 37 of Set 7 | wuning
# Processing Record 38 of Set 7 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 39 of Set 7 | ossora
# Processing Record 40 of Set 7 | innisfail
# Processing Record 41 of Set 7 | mount darwin
# Processing Record 42 of Set 7 | dingle
# Processing Record 43 of Set 7 | aksu
# Processing Record 44 of Set 7 | ostrovnoy
# Processing Record 45 of Set 7 | khonuu
# City khonuu not found. Skipping...
# Processing Record 46 of Set 7 | cam ranh
# Processing Record 47 of Set 7 | puksoozero
# Processing Record 48 of Set 7 | ust-kut
# Processing Record 49 of Set 7 | hope
# Processing Record 50 of Set 7 | port hedland
# Processing Record 1 of Set 8 | colares
# Processing Record 2 of Set 8 | saleaula
# City saleaula not found. Skipping...
# Processing Record 3 of Set 8 | santa cruz
# Processing Record 4 of Set 8 | ozinki
# Processing Record 5 of Set 8 | hattiesburg
# Processing Record 6 of Set 8 | chokurdakh
# Processing Record 7 of Set 8 | ilulissat
# Processing Record 8 of Set 8 | cidreira
# Processing Record 9 of Set 8 | arlit
# Processing Record 10 of Set 8 | vikulovo
# Processing Record 11 of Set 8 | skalistyy
# City skalistyy not found. Skipping...
# Processing Record 12 of Set 8 | tuburan
# Processing Record 13 of Set 8 | japura
# Processing Record 14 of Set 8 | bulgan
# Processing Record 15 of Set 8 | nikolskoye
# Processing Record 16 of Set 8 | sao joao da barra
# Processing Record 17 of Set 8 | tilichiki
# Processing Record 18 of Set 8 | kushiro
# Processing Record 19 of Set 8 | xuddur
# Processing Record 20 of Set 8 | coquimbo
# Processing Record 21 of Set 8 | ponta delgada
# Processing Record 22 of Set 8 | severo-yeniseyskiy
# Processing Record 23 of Set 8 | waterfoot
# Processing Record 24 of Set 8 | hami
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | miquelon
# Processing Record 27 of Set 8 | fairbanks
# Processing Record 28 of Set 8 | bonfim
# Processing Record 29 of Set 8 | nador
# Processing Record 30 of Set 8 | waingapu
# Processing Record 31 of Set 8 | paris
# Processing Record 32 of Set 8 | santa isabel
# Processing Record 33 of Set 8 | bariadi
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | samusu
# City samusu not found. Skipping...
# Processing Record 36 of Set 8 | vavatenina
# Processing Record 37 of Set 8 | cockburn harbour
# City cockburn harbour not found. Skipping...
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | rovaniemi
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | den helder
# Processing Record 42 of Set 8 | ixtapa
# Processing Record 43 of Set 8 | pedernales
# Processing Record 44 of Set 8 | port moresby
# Processing Record 45 of Set 8 | rio grande
# Processing Record 46 of Set 8 | nelson bay
# Processing Record 47 of Set 8 | harper
# Processing Record 48 of Set 8 | cherskiy
# Processing Record 49 of Set 8 | berberati
# Processing Record 50 of Set 8 | hualmay
# Processing Record 1 of Set 9 | kontagora
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | noumea
# Processing Record 4 of Set 9 | agua verde
# Processing Record 5 of Set 9 | kevsala
# Processing Record 6 of Set 9 | santa ana de yusguare
# Processing Record 7 of Set 9 | aykhal
# Processing Record 8 of Set 9 | nokaneng
# Processing Record 9 of Set 9 | karaul
# City karaul not found. Skipping...
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | hajnowka
# Processing Record 12 of Set 9 | katherine
# Processing Record 13 of Set 9 | barcelona
# Processing Record 14 of Set 9 | batticaloa
# Processing Record 15 of Set 9 | kabinda
# Processing Record 16 of Set 9 | viedma
# Processing Record 17 of Set 9 | mmabatho
# Processing Record 18 of Set 9 | vilyuysk
# Processing Record 19 of Set 9 | ordu
# Processing Record 20 of Set 9 | bullhead city
# Processing Record 21 of Set 9 | ulladulla
# Processing Record 22 of Set 9 | ayagoz
# Processing Record 23 of Set 9 | tombouctou
# Processing Record 24 of Set 9 | krutinka
# Processing Record 25 of Set 9 | hindoria
# Processing Record 26 of Set 9 | kodiak
# Processing Record 27 of Set 9 | santiago del estero
# Processing Record 28 of Set 9 | madras
# Processing Record 29 of Set 9 | malacacheta
# Processing Record 30 of Set 9 | palmer
# Processing Record 31 of Set 9 | bom jesus da lapa
# Processing Record 32 of Set 9 | marzuq
# Processing Record 33 of Set 9 | nuevo ideal
# Processing Record 34 of Set 9 | sumbe
# Processing Record 35 of Set 9 | erzin
# Processing Record 36 of Set 9 | kyra
# Processing Record 37 of Set 9 | doka
# Processing Record 38 of Set 9 | aksarka
# Processing Record 39 of Set 9 | soyo
# Processing Record 40 of Set 9 | skhisma
# Processing Record 41 of Set 9 | alyangula
# Processing Record 42 of Set 9 | puerto colombia
# Processing Record 43 of Set 9 | vao
# Processing Record 44 of Set 9 | fevralsk
# City fevralsk not found. Skipping...
# Processing Record 45 of Set 9 | khartoum
# Processing Record 46 of Set 9 | anadyr
# Processing Record 47 of Set 9 | ketchikan
# Processing Record 48 of Set 9 | beringovskiy
# Processing Record 49 of Set 9 | iqaluit
# Processing Record 50 of Set 9 | alice springs
# Processing Record 1 of Set 10 | canon city
# Processing Record 2 of Set 10 | srednekolymsk
# Processing Record 3 of Set 10 | pedasi
# Processing Record 4 of Set 10 | maxixe
# Processing Record 5 of Set 10 | abatskoye
# Processing Record 6 of Set 10 | merauke
# Processing Record 7 of Set 10 | san quintin
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | yuncheng
# Processing Record 10 of Set 10 | mahendragarh
# Processing Record 11 of Set 10 | titay
# Processing Record 12 of Set 10 | pemberton
# Processing Record 13 of Set 10 | north platte
# Processing Record 14 of Set 10 | zigong
# Processing Record 15 of Set 10 | pacific grove
# Processing Record 16 of Set 10 | orlik
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | nanortalik
# Processing Record 19 of Set 10 | seymchan
# Processing Record 20 of Set 10 | kalemie
# Processing Record 21 of Set 10 | high level
# Processing Record 22 of Set 10 | touros
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | margate
# Processing Record 25 of Set 10 | ariquemes
# Processing Record 26 of Set 10 | palabuhanratu
# City palabuhanratu not found. Skipping...
# Processing Record 27 of Set 10 | sjovegan
# Processing Record 28 of Set 10 | panaba
# Processing Record 29 of Set 10 | jardim
# Processing Record 30 of Set 10 | tateyama
# Processing Record 31 of Set 10 | temaraia
# City temaraia not found. Skipping...
# Processing Record 32 of Set 10 | pa sang
# Processing Record 33 of Set 10 | mitsamiouli
# Processing Record 34 of Set 10 | praia da vitoria
# Processing Record 35 of Set 10 | leningradskiy
# Processing Record 36 of Set 10 | broken hill
# Processing Record 37 of Set 10 | honolulu
# Processing Record 38 of Set 10 | rafaela
# Processing Record 39 of Set 10 | sao jose da coroa grande
# Processing Record 40 of Set 10 | omboue
# Processing Record 41 of Set 10 | andenes
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | nastola
# Processing Record 44 of Set 10 | atar
# Processing Record 45 of Set 10 | brodokalmak
# Processing Record 46 of Set 10 | coahuayana
# Processing Record 47 of Set 10 | pozo colorado
# Processing Record 48 of Set 10 | honiara
# Processing Record 49 of Set 10 | waipawa
# Processing Record 50 of Set 10 | henzada
# City henzada not found. Skipping...
# Processing Record 1 of Set 11 | castres
# Processing Record 2 of Set 11 | ahumada
# City ahumada not found. Skipping...
# Processing Record 3 of Set 11 | ca mau
# Processing Record 4 of Set 11 | keshan
# City keshan not found. Skipping...
# Processing Record 5 of Set 11 | sept-iles
# Processing Record 6 of Set 11 | ipswich
# Processing Record 7 of Set 11 | carlsbad
# Processing Record 8 of Set 11 | idrinskoye
# Processing Record 9 of Set 11 | ramshir
# Processing Record 10 of Set 11 | san vicente
# Processing Record 11 of Set 11 | medea
# Processing Record 12 of Set 11 | jimma
# Processing Record 13 of Set 11 | sechura
# Processing Record 14 of Set 11 | avera
# Processing Record 15 of Set 11 | dunedin
# Processing Record 16 of Set 11 | rocha
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | lensk
# Processing Record 19 of Set 11 | dobryanka
# Processing Record 20 of Set 11 | constitucion
# Processing Record 21 of Set 11 | kosh-agach
# Processing Record 22 of Set 11 | terrace
# Processing Record 23 of Set 11 | kudat
# Processing Record 24 of Set 11 | cayeli
# Processing Record 25 of Set 11 | yialos
# City yialos not found. Skipping...
# Processing Record 26 of Set 11 | oussouye
# Processing Record 27 of Set 11 | cesano maderno
# Processing Record 28 of Set 11 | makokou
# Processing Record 29 of Set 11 | madison
# Processing Record 30 of Set 11 | marcona
# City marcona not found. Skipping...
# Processing Record 31 of Set 11 | velyka bahachka
# Processing Record 32 of Set 11 | mao
# Processing Record 33 of Set 11 | yerbogachen
# Processing Record 34 of Set 11 | salair
# Processing Record 35 of Set 11 | felipe carrillo puerto
# Processing Record 36 of Set 11 | acarau
# Processing Record 37 of Set 11 | flinders
# Processing Record 38 of Set 11 | lima
# Processing Record 39 of Set 11 | antalya
# Processing Record 40 of Set 11 | maua
# Processing Record 41 of Set 11 | whitehorse
# Processing Record 42 of Set 11 | lolua
# City lolua not found. Skipping...
# Processing Record 43 of Set 11 | skanevik
# City skanevik not found. Skipping...
# Processing Record 44 of Set 11 | partizanskoye
# Processing Record 45 of Set 11 | safford
# Processing Record 46 of Set 11 | kahta
# Processing Record 47 of Set 11 | henties bay
# Processing Record 48 of Set 11 | helong
# Processing Record 49 of Set 11 | majene
# Processing Record 50 of Set 11 | kisangani
# Processing Record 1 of Set 12 | iskateley
# Processing Record 2 of Set 12 | cumaribo
# City cumaribo not found. Skipping...
# Processing Record 3 of Set 12 | cap malheureux
# Processing Record 4 of Set 12 | myitkyina
# Processing Record 5 of Set 12 | taoudenni
# Processing Record 6 of Set 12 | goose creek
# Processing Record 7 of Set 12 | porto walter
# Processing Record 8 of Set 12 | karlskoga
# Processing Record 9 of Set 12 | satitoa
# City satitoa not found. Skipping...
# Processing Record 10 of Set 12 | arrecife
# Processing Record 11 of Set 12 | axim
# Processing Record 12 of Set 12 | bur gabo
# City bur gabo not found. Skipping...
# Processing Record 13 of Set 12 | iquique
# Processing Record 14 of Set 12 | okha
# Processing Record 15 of Set 12 | raurkela
# City raurkela not found. Skipping...
# Processing Record 16 of Set 12 | sharjah
# Processing Record 17 of Set 12 | paducah
# Processing Record 18 of Set 12 | magadan
# Processing Record 19 of Set 12 | manhuacu
# Processing Record 20 of Set 12 | weligama
# Processing Record 21 of Set 12 | kutum
# Processing Record 22 of Set 12 | tecoanapa
# Processing Record 23 of Set 12 | ankazobe
# Processing Record 24 of Set 12 | puerto leguizamo
# Processing Record 25 of Set 12 | palwal
# Processing Record 26 of Set 12 | eenhana
# Processing Record 27 of Set 12 | ramjibanpur
# Processing Record 28 of Set 12 | kastamonu
# Processing Record 29 of Set 12 | katastarion
# Processing Record 30 of Set 12 | grand-lahou
# Processing Record 31 of Set 12 | bac lieu
# Processing Record 32 of Set 12 | maloy
# Processing Record 33 of Set 12 | mersing
# Processing Record 34 of Set 12 | villazon
# Processing Record 35 of Set 12 | seoul
# Processing Record 36 of Set 12 | nome
# Processing Record 37 of Set 12 | bereda
# Processing Record 38 of Set 12 | ndele
# Processing Record 39 of Set 12 | kone
# Processing Record 40 of Set 12 | tiarei
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | rawson
# Processing Record 43 of Set 12 | ulaanbaatar
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | sernur
# Processing Record 46 of Set 12 | dubuque
# Processing Record 47 of Set 12 | san patricio
# Processing Record 48 of Set 12 | jacareacanga
# Processing Record 49 of Set 12 | jiexiu
# Processing Record 50 of Set 12 | tubruq
# City tubruq not found. Skipping...
# Processing Record 1 of Set 13 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 2 of Set 13 | bardiyah
# Processing Record 3 of Set 13 | palaikastron
# Processing Record 4 of Set 13 | angangxi
# City angangxi not found. Skipping...
# Processing Record 5 of Set 13 | maarianhamina
# Processing Record 6 of Set 13 | goderich
# Processing Record 7 of Set 13 | feijo
# Processing Record 8 of Set 13 | minot
# Processing Record 9 of Set 13 | mayor pablo lagerenza
# Processing Record 10 of Set 13 | cheyenne
# Processing Record 11 of Set 13 | pokhara
# Processing Record 12 of Set 13 | collierville
# Processing Record 13 of Set 13 | ruatoria
# City ruatoria not found. Skipping...
# Processing Record 14 of Set 13 | cotonou
# Processing Record 15 of Set 13 | balikpapan
# Processing Record 16 of Set 13 | gwadar
# Processing Record 17 of Set 13 | kijang
# Processing Record 18 of Set 13 | nara
# Processing Record 19 of Set 13 | tabas
# Processing Record 20 of Set 13 | esmeraldas
# Processing Record 21 of Set 13 | dharchula
# Processing Record 22 of Set 13 | chaozhou
# Processing Record 23 of Set 13 | kroya
# Processing Record 24 of Set 13 | dauriya
# Processing Record 25 of Set 13 | richards bay
# Processing Record 26 of Set 13 | palimbang
# Processing Record 27 of Set 13 | tamisan
# Processing Record 28 of Set 13 | kamoke
# Processing Record 29 of Set 13 | kamenskoye
# City kamenskoye not found. Skipping...
# Processing Record 30 of Set 13 | walvis bay
# Processing Record 31 of Set 13 | gatesville
# Processing Record 32 of Set 13 | pacifica
# Processing Record 33 of Set 13 | selty
# Processing Record 34 of Set 13 | shimoda
# Processing Record 35 of Set 13 | pathein
# Processing Record 36 of Set 13 | moose factory
# Processing Record 37 of Set 13 | ucluelet
# Processing Record 38 of Set 13 | ibra
# Processing Record 39 of Set 13 | bassila
# Processing Record 40 of Set 13 | the valley
# Processing Record 41 of Set 13 | dourbali
# Processing Record 42 of Set 13 | urengoy
# Processing Record 43 of Set 13 | kolchugino
# Processing Record 44 of Set 13 | yining
# Processing Record 45 of Set 13 | natal
# Processing Record 46 of Set 13 | chapais
# Processing Record 47 of Set 13 | bargal
# City bargal not found. Skipping...
# Processing Record 48 of Set 13 | korla
# Processing Record 49 of Set 13 | koungheul
# Processing Record 50 of Set 13 | maceio
# Processing Record 1 of Set 14 | batangafo
# Processing Record 2 of Set 14 | imeni vorovskogo
# Processing Record 3 of Set 14 | kopavogur
# Processing Record 4 of Set 14 | khandbari
# Processing Record 5 of Set 14 | pangai
# Processing Record 6 of Set 14 | amapa
# Processing Record 7 of Set 14 | banjar
# Processing Record 8 of Set 14 | erenhot
# Processing Record 9 of Set 14 | emba
# Processing Record 10 of Set 14 | thirion
# City thirion not found. Skipping...
# Processing Record 11 of Set 14 | kalmar
# Processing Record 12 of Set 14 | isa khel
# Processing Record 13 of Set 14 | taburi
# City taburi not found. Skipping...
# Processing Record 14 of Set 14 | iisalmi
# Processing Record 15 of Set 14 | grajau
# Processing Record 16 of Set 14 | boffa
# Processing Record 17 of Set 14 | sambava
# Processing Record 18 of Set 14 | nguiu
# City nguiu not found. Skipping...
# Processing Record 19 of Set 14 | riyadh
# Processing Record 20 of Set 14 | shingu
# Processing Record 21 of Set 14 | dalvik
# Processing Record 22 of Set 14 | bure
# Processing Record 23 of Set 14 | hofn
# Processing Record 24 of Set 14 | gazli
# Processing Record 25 of Set 14 | galveston
# Processing Record 26 of Set 14 | huangpi
# Processing Record 27 of Set 14 | camacari
# Processing Record 28 of Set 14 | tarakan
# Processing Record 29 of Set 14 | bandarbeyla
# Processing Record 30 of Set 14 | zhangye
# Processing Record 31 of Set 14 | gotsu
# Processing Record 32 of Set 14 | novyy yarychiv
# Processing Record 33 of Set 14 | pasni
# Processing Record 34 of Set 14 | port macquarie
# Processing Record 35 of Set 14 | ventersburg
# Processing Record 36 of Set 14 | anito
# Processing Record 37 of Set 14 | otradnoye
# Processing Record 38 of Set 14 | shouguang
# Processing Record 39 of Set 14 | yomou
# Processing Record 40 of Set 14 | panyutyne
# Processing Record 41 of Set 14 | boa vista
# Processing Record 42 of Set 14 | navolato
# Processing Record 43 of Set 14 | velizh
# Processing Record 44 of Set 14 | mugur-aksy
# Processing Record 45 of Set 14 | lazaro cardenas
# Processing Record 46 of Set 14 | rancho palos verdes
# Processing Record 47 of Set 14 | imbituba
# Processing Record 48 of Set 14 | urumqi
# Processing Record 49 of Set 14 | saint-jean-port-joli
# Processing Record 50 of Set 14 | doctor pedro p. pena
# City doctor pedro p. pena not found. Skipping...
# Processing Record 1 of Set 15 | albertville
# Processing Record 2 of Set 15 | gravdal
# Processing Record 3 of Set 15 | bintulu
# Processing Record 4 of Set 15 | eyl
# Processing Record 5 of Set 15 | uddevalla
# Processing Record 6 of Set 15 | praia
# Processing Record 7 of Set 15 | beidao
# Processing Record 8 of Set 15 | bogande
# Processing Record 9 of Set 15 | lasa
# Processing Record 10 of Set 15 | aviles
# Processing Record 11 of Set 15 | ozernovskiy
# Processing Record 12 of Set 15 | sheltozero
# Processing Record 13 of Set 15 | fare
# Processing Record 14 of Set 15 | nong chik
# Processing Record 15 of Set 15 | bolshiye chapurniki
# City bolshiye chapurniki not found. Skipping...
# Processing Record 16 of Set 15 | roebourne
# Processing Record 17 of Set 15 | treinta y tres
# Processing Record 18 of Set 15 | olenino
# Processing Record 19 of Set 15 | ampanihy
# Processing Record 20 of Set 15 | bilma
# Processing Record 21 of Set 15 | puerto del rosario
# Processing Record 22 of Set 15 | kabare
# Processing Record 23 of Set 15 | sandnessjoen
# Processing Record 24 of Set 15 | verkhnevilyuysk
# Processing Record 25 of Set 15 | burgess hill
# Processing Record 26 of Set 15 | ornes
# Processing Record 27 of Set 15 | teahupoo
# Processing Record 28 of Set 15 | vestmannaeyjar
# Processing Record 29 of Set 15 | krasnovishersk
# Processing Record 30 of Set 15 | gisborne
# Processing Record 31 of Set 15 | qingdao
# Processing Record 32 of Set 15 | qinzhou
# Processing Record 33 of Set 15 | turukhansk
# Processing Record 34 of Set 15 | nizwa
# Processing Record 35 of Set 15 | porto velho
# Processing Record 36 of Set 15 | laguna de perlas
# Processing Record 37 of Set 15 | lemesos
# City lemesos not found. Skipping...
# Processing Record 38 of Set 15 | iroquois falls
# Processing Record 39 of Set 15 | ruston
# Processing Record 40 of Set 15 | hammerfest
# Processing Record 41 of Set 15 | tommot
# Processing Record 42 of Set 15 | tsabong
# Processing Record 43 of Set 15 | la asuncion
# Processing Record 44 of Set 15 | staszow
# Processing Record 45 of Set 15 | ocos
# Processing Record 46 of Set 15 | kurilsk
# Processing Record 47 of Set 15 | barawe
# City barawe not found. Skipping...
# Processing Record 48 of Set 15 | port arthur
# Processing Record 49 of Set 15 | monrovia
# Processing Record 50 of Set 15 | de-kastri
# Processing Record 1 of Set 16 | hunza
# City hunza not found. Skipping...
# Processing Record 2 of Set 16 | maryborough
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mana      GF   5.66  -53.78     78.76        88           8
# 1  North Bend      US  43.41 -124.22     81.00        72           1
# 2  Ogdensburg      US  44.69  -75.49     64.00        93          20
# 3      Olinda      BR  -8.01  -34.86     78.80        78          75
# 4       Upata      VE   8.01  -62.40     82.00        76          32
# 5      Albany      US  42.60  -73.97     68.00        82         100
# 6      Zhuhai      CN  22.28  113.57     86.00        84          20
# 7      Hobart      AU -42.88  147.33     57.99        58          75
# 8       Muros      ES  42.78   -9.06     57.00        93           5
# 9      Dikson      RU  73.51   80.55     48.07        83          84
#
#    Wind Speed Current Description
# 0        5.14           clear sky
# 1       25.28           clear sky
# 2        3.89          few clouds
# 3       10.29       broken clouds
# 4        1.99    scattered clouds
# 5        1.54     overcast clouds
# 6        3.36          few clouds
# 7       13.87       broken clouds
# 8        1.01           clear sky
# 9        6.82       broken clouds

# %%
# Export the City_Data into a CSV.
city_weather_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')
