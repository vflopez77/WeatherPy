# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
import citipy
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build basic URL
from config import weather_base_url
url = f"{weather_base_url}{weather_api_key}"

# %%
# Get all the city weather data
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})
                          #                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print(f"City {city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | beringovskiy
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | louisbourg
# City louisbourg not found. Skipping...
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | omsukchan
# Processing Record 9 of Set 1 | cap malheureux
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | smolenka
# Processing Record 14 of Set 1 | hualmay
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | portel
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | astana
# Processing Record 20 of Set 1 | san pedro de macoris
# Processing Record 21 of Set 1 | mackenzie
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | port augusta
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | hobyo
# Processing Record 29 of Set 1 | san rafael
# Processing Record 30 of Set 1 | bondo
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | lunenburg
# Processing Record 33 of Set 1 | marsabit
# Processing Record 34 of Set 1 | manhush
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | nantucket
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | sarana
# Processing Record 39 of Set 1 | khandagayty
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | paramonga
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | kuche
# City kuche not found. Skipping...
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | haines junction
# Processing Record 50 of Set 1 | tateyama
# Processing Record 1 of Set 2 | poum
# Processing Record 2 of Set 2 | lexington park
# Processing Record 3 of Set 2 | visnes
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | ugento
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | key largo
# Processing Record 9 of Set 2 | mayumba
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | muriwai beach
# Processing Record 12 of Set 2 | camacha
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | pacifica
# Processing Record 16 of Set 2 | taunggyi
# Processing Record 17 of Set 2 | birao
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | martapura
# Processing Record 23 of Set 2 | karkaralinsk
# City karkaralinsk not found. Skipping...
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | zyryanka
# Processing Record 26 of Set 2 | viedma
# Processing Record 27 of Set 2 | havelock
# Processing Record 28 of Set 2 | tawkar
# City tawkar not found. Skipping...
# Processing Record 29 of Set 2 | rungata
# City rungata not found. Skipping...
# Processing Record 30 of Set 2 | vaitupu
# City vaitupu not found. Skipping...
# Processing Record 31 of Set 2 | half moon bay
# Processing Record 32 of Set 2 | bandiagara
# Processing Record 33 of Set 2 | panjakent
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | leningradskiy
# Processing Record 37 of Set 2 | kapurthala
# Processing Record 38 of Set 2 | esmeralda
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | fernandez
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | kuruman
# Processing Record 43 of Set 2 | mys shmidta
# City mys shmidta not found. Skipping...
# Processing Record 44 of Set 2 | ornskoldsvik
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | yulara
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | pakala
# Processing Record 49 of Set 2 | cockburn town
# Processing Record 50 of Set 2 | sioux lookout
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | pacific grove
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | tongchuan
# Processing Record 6 of Set 3 | casa grande
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | kavaratti
# Processing Record 9 of Set 3 | parchim
# Processing Record 10 of Set 3 | tiksi
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | port-gentil
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | zhitikara
# City zhitikara not found. Skipping...
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | palabuhanratu
# City palabuhanratu not found. Skipping...
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | fort walton beach
# Processing Record 20 of Set 3 | malwan
# City malwan not found. Skipping...
# Processing Record 21 of Set 3 | te anau
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | sentyabrskiy
# City sentyabrskiy not found. Skipping...
# Processing Record 24 of Set 3 | lorengau
# Processing Record 25 of Set 3 | ginir
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | general roca
# Processing Record 28 of Set 3 | dunmore town
# Processing Record 29 of Set 3 | puerto narino
# Processing Record 30 of Set 3 | rakai
# Processing Record 31 of Set 3 | halalo
# City halalo not found. Skipping...
# Processing Record 32 of Set 3 | charlestown
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | amderma
# City amderma not found. Skipping...
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | talas
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | taolanaro
# City taolanaro not found. Skipping...
# Processing Record 41 of Set 3 | elbrus
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | chumikan
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | parrita
# Processing Record 46 of Set 3 | solenzo
# Processing Record 47 of Set 3 | yellowknife
# Processing Record 48 of Set 3 | barentsburg
# City barentsburg not found. Skipping...
# Processing Record 49 of Set 3 | phalodi
# Processing Record 50 of Set 3 | kirkwood
# Processing Record 1 of Set 4 | balkanabat
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | nalut
# Processing Record 4 of Set 4 | mahebourg
# Processing Record 5 of Set 4 | sabang
# Processing Record 6 of Set 4 | hanzhong
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | scarborough
# Processing Record 11 of Set 4 | chernyshevskiy
# Processing Record 12 of Set 4 | akdepe
# Processing Record 13 of Set 4 | san pedro
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | puerto ayora
# Processing Record 16 of Set 4 | saleaula
# City saleaula not found. Skipping...
# Processing Record 17 of Set 4 | mahajanga
# Processing Record 18 of Set 4 | khatanga
# Processing Record 19 of Set 4 | wahran
# City wahran not found. Skipping...
# Processing Record 20 of Set 4 | meulaboh
# Processing Record 21 of Set 4 | namatanai
# Processing Record 22 of Set 4 | ambovombe
# Processing Record 23 of Set 4 | shelburne
# Processing Record 24 of Set 4 | mandalgovi
# Processing Record 25 of Set 4 | saint-jacques
# Processing Record 26 of Set 4 | issenye
# Processing Record 27 of Set 4 | suwannaphum
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | jaru
# Processing Record 30 of Set 4 | plon
# Processing Record 31 of Set 4 | torbat-e jam
# Processing Record 32 of Set 4 | puerto del rosario
# Processing Record 33 of Set 4 | kapaa
# Processing Record 34 of Set 4 | palmerston
# Processing Record 35 of Set 4 | hasaki
# Processing Record 36 of Set 4 | constanza
# Processing Record 37 of Set 4 | sri aman
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | troitsko-pechorsk
# Processing Record 40 of Set 4 | storforshei
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | vysokogornyy
# Processing Record 43 of Set 4 | karimganj
# Processing Record 44 of Set 4 | dingle
# Processing Record 45 of Set 4 | marsh harbour
# Processing Record 46 of Set 4 | vaini
# Processing Record 47 of Set 4 | san policarpo
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | pevek
# Processing Record 50 of Set 4 | miranda
# Processing Record 1 of Set 5 | plattsburgh
# Processing Record 2 of Set 5 | tukrah
# Processing Record 3 of Set 5 | nieuw amsterdam
# Processing Record 4 of Set 5 | kodinsk
# Processing Record 5 of Set 5 | ahipara
# Processing Record 6 of Set 5 | biu
# Processing Record 7 of Set 5 | hilo
# Processing Record 8 of Set 5 | pochutla
# Processing Record 9 of Set 5 | samusu
# City samusu not found. Skipping...
# Processing Record 10 of Set 5 | hermiston
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | vagur
# Processing Record 13 of Set 5 | irbil
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | belmonte
# Processing Record 16 of Set 5 | sitges
# Processing Record 17 of Set 5 | ust-omchug
# Processing Record 18 of Set 5 | lazaro cardenas
# Processing Record 19 of Set 5 | scottsburgh
# City scottsburgh not found. Skipping...
# Processing Record 20 of Set 5 | castro
# Processing Record 21 of Set 5 | sungaipenuh
# Processing Record 22 of Set 5 | saint john
# Processing Record 23 of Set 5 | luanda
# Processing Record 24 of Set 5 | arman
# Processing Record 25 of Set 5 | ust-nera
# Processing Record 26 of Set 5 | rudbar
# Processing Record 27 of Set 5 | port macquarie
# Processing Record 28 of Set 5 | krasnyy oktyabr
# Processing Record 29 of Set 5 | tocopilla
# Processing Record 30 of Set 5 | dzhebariki-khaya
# Processing Record 31 of Set 5 | kingston
# Processing Record 32 of Set 5 | isangel
# Processing Record 33 of Set 5 | monrovia
# Processing Record 34 of Set 5 | jining
# Processing Record 35 of Set 5 | homer
# Processing Record 36 of Set 5 | young
# Processing Record 37 of Set 5 | navalmoral de la mata
# Processing Record 38 of Set 5 | soe
# Processing Record 39 of Set 5 | micheweni
# Processing Record 40 of Set 5 | san quintin
# Processing Record 41 of Set 5 | shingu
# Processing Record 42 of Set 5 | requena
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | georgetown
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | alibag
# Processing Record 47 of Set 5 | yining
# Processing Record 48 of Set 5 | laguna
# Processing Record 49 of Set 5 | catamarca
# Processing Record 50 of Set 5 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping...
# Processing Record 1 of Set 6 | mackay
# Processing Record 2 of Set 6 | myitkyina
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | wucheng
# Processing Record 5 of Set 6 | grand river south east
# City grand river south east not found. Skipping...
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | kambove
# Processing Record 8 of Set 6 | vestmanna
# Processing Record 9 of Set 6 | nome
# Processing Record 10 of Set 6 | itoman
# Processing Record 11 of Set 6 | walvis bay
# Processing Record 12 of Set 6 | belushya guba
# City belushya guba not found. Skipping...
# Processing Record 13 of Set 6 | havoysund
# Processing Record 14 of Set 6 | tsihombe
# City tsihombe not found. Skipping...
# Processing Record 15 of Set 6 | little current
# Processing Record 16 of Set 6 | concepcion
# Processing Record 17 of Set 6 | tura
# Processing Record 18 of Set 6 | greeneville
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | primorsk
# Processing Record 21 of Set 6 | roald
# Processing Record 22 of Set 6 | lodja
# Processing Record 23 of Set 6 | ouallam
# Processing Record 24 of Set 6 | bambous virieux
# Processing Record 25 of Set 6 | conselheiro pena
# Processing Record 26 of Set 6 | cidreira
# Processing Record 27 of Set 6 | mukhtolovo
# Processing Record 28 of Set 6 | komsomolskiy
# Processing Record 29 of Set 6 | tepeapulco
# Processing Record 30 of Set 6 | jalu
# Processing Record 31 of Set 6 | sao joao da barra
# Processing Record 32 of Set 6 | uvarovo
# Processing Record 33 of Set 6 | padang
# Processing Record 34 of Set 6 | nishihara
# Processing Record 35 of Set 6 | abu ghosh
# Processing Record 36 of Set 6 | edson
# Processing Record 37 of Set 6 | mulanje
# Processing Record 38 of Set 6 | west fargo
# Processing Record 39 of Set 6 | ontario
# Processing Record 40 of Set 6 | yenagoa
# Processing Record 41 of Set 6 | vernon
# Processing Record 42 of Set 6 | tigil
# Processing Record 43 of Set 6 | boa vista
# Processing Record 44 of Set 6 | ahuimanu
# Processing Record 45 of Set 6 | timizart
# Processing Record 46 of Set 6 | sungairaya
# Processing Record 47 of Set 6 | ambilobe
# Processing Record 48 of Set 6 | pirgos
# Processing Record 49 of Set 6 | riyadh
# Processing Record 50 of Set 6 | gouyave
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | marcona
# City marcona not found. Skipping...
# Processing Record 4 of Set 7 | omboue
# Processing Record 5 of Set 7 | caibarien
# Processing Record 6 of Set 7 | tymovskoye
# Processing Record 7 of Set 7 | aqtobe
# Processing Record 8 of Set 7 | loandjili
# Processing Record 9 of Set 7 | la rioja
# Processing Record 10 of Set 7 | ixtapa
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | kieta
# Processing Record 13 of Set 7 | trairi
# Processing Record 14 of Set 7 | pemberton
# Processing Record 15 of Set 7 | husavik
# Processing Record 16 of Set 7 | tonantins
# Processing Record 17 of Set 7 | gatesville
# Processing Record 18 of Set 7 | iskateley
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | sao gabriel da cachoeira
# Processing Record 21 of Set 7 | luderitz
# Processing Record 22 of Set 7 | coevorden
# Processing Record 23 of Set 7 | porto tolle
# Processing Record 24 of Set 7 | nanga eboko
# Processing Record 25 of Set 7 | thessalon
# Processing Record 26 of Set 7 | egvekinot
# Processing Record 27 of Set 7 | hami
# Processing Record 28 of Set 7 | hervey bay
# Processing Record 29 of Set 7 | batagay-alyta
# Processing Record 30 of Set 7 | manavalakurichi
# Processing Record 31 of Set 7 | brookings
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | tasiilaq
# Processing Record 34 of Set 7 | asau
# Processing Record 35 of Set 7 | okha
# Processing Record 36 of Set 7 | lata
# Processing Record 37 of Set 7 | mayo
# Processing Record 38 of Set 7 | ihosy
# Processing Record 39 of Set 7 | luganville
# Processing Record 40 of Set 7 | caravelas
# Processing Record 41 of Set 7 | cuamba
# Processing Record 42 of Set 7 | bengkulu
# Processing Record 43 of Set 7 | batagay
# Processing Record 44 of Set 7 | shimoda
# Processing Record 45 of Set 7 | diffa
# Processing Record 46 of Set 7 | grand-lahou
# Processing Record 47 of Set 7 | coquimbo
# Processing Record 48 of Set 7 | abu dhabi
# Processing Record 49 of Set 7 | tomatlan
# Processing Record 50 of Set 7 | margate
# Processing Record 1 of Set 8 | antigonish
# Processing Record 2 of Set 8 | muros
# Processing Record 3 of Set 8 | adrar
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | gigmoto
# Processing Record 6 of Set 8 | araouane
# Processing Record 7 of Set 8 | dudinka
# Processing Record 8 of Set 8 | ife
# Processing Record 9 of Set 8 | bati
# Processing Record 10 of Set 8 | kargasok
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | jian
# Processing Record 13 of Set 8 | langen
# Processing Record 14 of Set 8 | sterling
# Processing Record 15 of Set 8 | barawe
# City barawe not found. Skipping...
# Processing Record 16 of Set 8 | ngunguru
# Processing Record 17 of Set 8 | guanagazapa
# Processing Record 18 of Set 8 | jumla
# Processing Record 19 of Set 8 | mount gambier
# Processing Record 20 of Set 8 | ambon
# Processing Record 21 of Set 8 | temaraia
# City temaraia not found. Skipping...
# Processing Record 22 of Set 8 | cabedelo
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | jiayuguan
# Processing Record 25 of Set 8 | coihaique
# Processing Record 26 of Set 8 | novyy urengoy
# Processing Record 27 of Set 8 | severnyy
# Processing Record 28 of Set 8 | jieshi
# Processing Record 29 of Set 8 | ternate
# Processing Record 30 of Set 8 | dolbeau
# City dolbeau not found. Skipping...
# Processing Record 31 of Set 8 | bathsheba
# Processing Record 32 of Set 8 | pisco
# Processing Record 33 of Set 8 | codajas
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | calderitas
# Processing Record 36 of Set 8 | manjacaze
# Processing Record 37 of Set 8 | aland
# Processing Record 38 of Set 8 | comal
# Processing Record 39 of Set 8 | kailua
# Processing Record 40 of Set 8 | sinnamary
# Processing Record 41 of Set 8 | santa isabel do rio negro
# Processing Record 42 of Set 8 | santa cruz del norte
# Processing Record 43 of Set 8 | alexandria
# Processing Record 44 of Set 8 | palmas
# Processing Record 45 of Set 8 | kindia
# Processing Record 46 of Set 8 | faya
# Processing Record 47 of Set 8 | barcelos
# Processing Record 48 of Set 8 | honiara
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | dakar
# Processing Record 2 of Set 9 | bonavista
# Processing Record 3 of Set 9 | zaysan
# Processing Record 4 of Set 9 | tabiauea
# City tabiauea not found. Skipping...
# Processing Record 5 of Set 9 | santa rosa
# Processing Record 6 of Set 9 | okandja
# City okandja not found. Skipping...
# Processing Record 7 of Set 9 | hefei
# Processing Record 8 of Set 9 | lasa
# Processing Record 9 of Set 9 | ulladulla
# Processing Record 10 of Set 9 | birjand
# Processing Record 11 of Set 9 | bantry
# Processing Record 12 of Set 9 | sampit
# Processing Record 13 of Set 9 | kenai
# Processing Record 14 of Set 9 | labuhan
# Processing Record 15 of Set 9 | torbay
# Processing Record 16 of Set 9 | kholm
# Processing Record 17 of Set 9 | sao felix do xingu
# Processing Record 18 of Set 9 | beloha
# Processing Record 19 of Set 9 | basco
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | sao miguel do araguaia
# Processing Record 22 of Set 9 | sale
# Processing Record 23 of Set 9 | maragogi
# Processing Record 24 of Set 9 | revelstoke
# Processing Record 25 of Set 9 | voh
# Processing Record 26 of Set 9 | trincomalee
# Processing Record 27 of Set 9 | cordoba
# Processing Record 28 of Set 9 | suluq
# Processing Record 29 of Set 9 | neiafu
# Processing Record 30 of Set 9 | huarmey
# Processing Record 31 of Set 9 | sabancuy
# Processing Record 32 of Set 9 | eureka
# Processing Record 33 of Set 9 | alihe
# Processing Record 34 of Set 9 | myaundzha
# Processing Record 35 of Set 9 | los llanos de aridane
# Processing Record 36 of Set 9 | tabou
# Processing Record 37 of Set 9 | mega
# Processing Record 38 of Set 9 | khasan
# Processing Record 39 of Set 9 | vila velha
# Processing Record 40 of Set 9 | saskylakh
# Processing Record 41 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 42 of Set 9 | palmer
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | bolungarvik
# City bolungarvik not found. Skipping...
# Processing Record 45 of Set 9 | marks
# Processing Record 46 of Set 9 | hofn
# Processing Record 47 of Set 9 | mitsamiouli
# Processing Record 48 of Set 9 | fairbanks
# Processing Record 49 of Set 9 | tidore
# City tidore not found. Skipping...
# Processing Record 50 of Set 9 | astoria
# Processing Record 1 of Set 10 | diego de almagro
# Processing Record 2 of Set 10 | doume
# Processing Record 3 of Set 10 | tessalit
# Processing Record 4 of Set 10 | ler
# Processing Record 5 of Set 10 | west wendover
# Processing Record 6 of Set 10 | pedasi
# Processing Record 7 of Set 10 | nirmali
# Processing Record 8 of Set 10 | oudtshoorn
# Processing Record 9 of Set 10 | saint anthony
# Processing Record 10 of Set 10 | tual
# Processing Record 11 of Set 10 | biak
# Processing Record 12 of Set 10 | yatou
# Processing Record 13 of Set 10 | zaranj
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | bilma
# Processing Record 17 of Set 10 | mocambique
# City mocambique not found. Skipping...
# Processing Record 18 of Set 10 | gidole
# Processing Record 19 of Set 10 | maniitsoq
# Processing Record 20 of Set 10 | ponta delgada
# Processing Record 21 of Set 10 | haibowan
# City haibowan not found. Skipping...
# Processing Record 22 of Set 10 | barranca
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | makakilo city
# Processing Record 25 of Set 10 | agde
# Processing Record 26 of Set 10 | richards bay
# Processing Record 27 of Set 10 | sao sepe
# Processing Record 28 of Set 10 | khorramshahr
# Processing Record 29 of Set 10 | turukhansk
# Processing Record 30 of Set 10 | acarau
# Processing Record 31 of Set 10 | talwandi bhai
# Processing Record 32 of Set 10 | cururupu
# Processing Record 33 of Set 10 | salisbury
# Processing Record 34 of Set 10 | tumannyy
# City tumannyy not found. Skipping...
# Processing Record 35 of Set 10 | aswan
# Processing Record 36 of Set 10 | grand gaube
# Processing Record 37 of Set 10 | yuanping
# Processing Record 38 of Set 10 | kolosovka
# Processing Record 39 of Set 10 | kennewick
# Processing Record 40 of Set 10 | healdsburg
# Processing Record 41 of Set 10 | umtata
# Processing Record 42 of Set 10 | kijang
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | atambua
# Processing Record 45 of Set 10 | tokmak
# Processing Record 46 of Set 10 | banda aceh
# Processing Record 47 of Set 10 | maningrida
# Processing Record 48 of Set 10 | wasco
# Processing Record 49 of Set 10 | mitu
# Processing Record 50 of Set 10 | bubaque
# Processing Record 1 of Set 11 | dawlatabad
# Processing Record 2 of Set 11 | ilulissat
# Processing Record 3 of Set 11 | tilichiki
# Processing Record 4 of Set 11 | golden
# Processing Record 5 of Set 11 | bowen
# Processing Record 6 of Set 11 | alofi
# Processing Record 7 of Set 11 | sur
# Processing Record 8 of Set 11 | luquillo
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | barguzin
# Processing Record 11 of Set 11 | san patricio
# Processing Record 12 of Set 11 | burnie
# Processing Record 13 of Set 11 | montepuez
# Processing Record 14 of Set 11 | deneysville
# Processing Record 15 of Set 11 | sitka
# Processing Record 16 of Set 11 | vrangel
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | hunza
# City hunza not found. Skipping...
# Processing Record 19 of Set 11 | amapa
# Processing Record 20 of Set 11 | kerema
# Processing Record 21 of Set 11 | udachnyy
# Processing Record 22 of Set 11 | henties bay
# Processing Record 23 of Set 11 | progreso
# Processing Record 24 of Set 11 | bosobolo
# Processing Record 25 of Set 11 | staryy merchyk
# Processing Record 26 of Set 11 | effingham
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | shahr-e kord
# Processing Record 29 of Set 11 | providencia
# Processing Record 30 of Set 11 | rapid valley
# Processing Record 31 of Set 11 | derzhavinsk
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | bairiki
# Processing Record 34 of Set 11 | pangnirtung
# Processing Record 35 of Set 11 | bengkalis
# City bengkalis not found. Skipping...
# Processing Record 36 of Set 11 | umba
# Processing Record 37 of Set 11 | broken hill
# Processing Record 38 of Set 11 | sangar
# Processing Record 39 of Set 11 | syasstroy
# Processing Record 40 of Set 11 | goryachiy klyuch
# Processing Record 41 of Set 11 | banyuwangi
# Processing Record 42 of Set 11 | muscat
# Processing Record 43 of Set 11 | rio esteban
# Processing Record 44 of Set 11 | mombaca
# Processing Record 45 of Set 11 | umm kaddadah
# Processing Record 46 of Set 11 | jiwani
# Processing Record 47 of Set 11 | road town
# Processing Record 48 of Set 11 | sunrise manor
# Processing Record 49 of Set 11 | mao
# Processing Record 50 of Set 11 | abu samrah
# Processing Record 1 of Set 12 | burns lake
# Processing Record 2 of Set 12 | liancheng
# Processing Record 3 of Set 12 | nioro
# Processing Record 4 of Set 12 | chengzihe
# Processing Record 5 of Set 12 | shestakovo
# Processing Record 6 of Set 12 | akyab
# Processing Record 7 of Set 12 | kungurtug
# Processing Record 8 of Set 12 | rotterdam
# Processing Record 9 of Set 12 | harper
# Processing Record 10 of Set 12 | nizhniy kuranakh
# Processing Record 11 of Set 12 | general pico
# Processing Record 12 of Set 12 | russell
# Processing Record 13 of Set 12 | manicore
# Processing Record 14 of Set 12 | lisala
# Processing Record 15 of Set 12 | nabire
# Processing Record 16 of Set 12 | mazagao
# Processing Record 17 of Set 12 | reconquista
# Processing Record 18 of Set 12 | bumbuna
# Processing Record 19 of Set 12 | lao cai
# Processing Record 20 of Set 12 | palauig
# Processing Record 21 of Set 12 | cochrane
# Processing Record 22 of Set 12 | oranjestad
# Processing Record 23 of Set 12 | paamiut
# Processing Record 24 of Set 12 | meyungs
# City meyungs not found. Skipping...
# Processing Record 25 of Set 12 | ardistan
# City ardistan not found. Skipping...
# Processing Record 26 of Set 12 | artyk
# City artyk not found. Skipping...
# Processing Record 27 of Set 12 | abha
# Processing Record 28 of Set 12 | carballo
# Processing Record 29 of Set 12 | al
# City al not found. Skipping...
# Processing Record 30 of Set 12 | zhicheng
# Processing Record 31 of Set 12 | nouakchott
# Processing Record 32 of Set 12 | lubango
# Processing Record 33 of Set 12 | sarkand
# Processing Record 34 of Set 12 | kyzyl-suu
# Processing Record 35 of Set 12 | karasjok
# Processing Record 36 of Set 12 | suez
# Processing Record 37 of Set 12 | salinopolis
# Processing Record 38 of Set 12 | enshi
# Processing Record 39 of Set 12 | puri
# Processing Record 40 of Set 12 | vardo
# Processing Record 41 of Set 12 | raudeberg
# Processing Record 42 of Set 12 | sergeyevka
# Processing Record 43 of Set 12 | port lavaca
# Processing Record 44 of Set 12 | priyutnoye
# Processing Record 45 of Set 12 | armacao dos buzios
# City armacao dos buzios not found. Skipping...
# Processing Record 46 of Set 12 | ljaskovec
# City ljaskovec not found. Skipping...
# Processing Record 47 of Set 12 | kysyl-syr
# Processing Record 48 of Set 12 | chara
# Processing Record 49 of Set 12 | nurota
# Processing Record 50 of Set 12 | boli
# Processing Record 1 of Set 13 | bakchar
# Processing Record 2 of Set 13 | villa carlos paz
# Processing Record 3 of Set 13 | alta floresta
# Processing Record 4 of Set 13 | gizo
# Processing Record 5 of Set 13 | byron bay
# Processing Record 6 of Set 13 | camana
# Processing Record 7 of Set 13 | comodoro rivadavia
# Processing Record 8 of Set 13 | muli
# Processing Record 9 of Set 13 | kizema
# Processing Record 10 of Set 13 | zhangye
# Processing Record 11 of Set 13 | coahuayana
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | tarumovka
# Processing Record 14 of Set 13 | kumluca
# Processing Record 15 of Set 13 | attawapiskat
# City attawapiskat not found. Skipping...
# Processing Record 16 of Set 13 | koumac
# Processing Record 17 of Set 13 | garden city
# Processing Record 18 of Set 13 | zhezkazgan
# Processing Record 19 of Set 13 | mountain home
# Processing Record 20 of Set 13 | tevriz
# Processing Record 21 of Set 13 | chalus
# Processing Record 22 of Set 13 | beyneu
# Processing Record 23 of Set 13 | filingue
# Processing Record 24 of Set 13 | bombay
# Processing Record 25 of Set 13 | gabaldon
# Processing Record 26 of Set 13 | altay
# Processing Record 27 of Set 13 | bacuit
# City bacuit not found. Skipping...
# Processing Record 28 of Set 13 | usinsk
# Processing Record 29 of Set 13 | shache
# Processing Record 30 of Set 13 | dwarahat
# Processing Record 31 of Set 13 | baker city
# Processing Record 32 of Set 13 | ekhabi
# Processing Record 33 of Set 13 | tokzar
# City tokzar not found. Skipping...
# Processing Record 34 of Set 13 | newberry
# Processing Record 35 of Set 13 | kingsland
# Processing Record 36 of Set 13 | olafsvik
# Processing Record 37 of Set 13 | longlac
# City longlac not found. Skipping...
# Processing Record 38 of Set 13 | santa cruz
# Processing Record 39 of Set 13 | flin flon
# Processing Record 40 of Set 13 | ahtopol
# Processing Record 41 of Set 13 | raga
# Processing Record 42 of Set 13 | tiel
# Processing Record 43 of Set 13 | conde
# Processing Record 44 of Set 13 | grand-santi
# Processing Record 45 of Set 13 | yeppoon
# Processing Record 46 of Set 13 | sattahip
# Processing Record 47 of Set 13 | payo
# Processing Record 48 of Set 13 | portland
# Processing Record 49 of Set 13 | lompoc
# Processing Record 50 of Set 13 | petatlan
# Processing Record 1 of Set 14 | grande prairie
# Processing Record 2 of Set 14 | mwinilunga
# Processing Record 3 of Set 14 | tambura
# Processing Record 4 of Set 14 | lethem
# Processing Record 5 of Set 14 | sistranda
# Processing Record 6 of Set 14 | envira
# Processing Record 7 of Set 14 | waingapu
# Processing Record 8 of Set 14 | hailar
# Processing Record 9 of Set 14 | kropotkin
# Processing Record 10 of Set 14 | cayenne
# Processing Record 11 of Set 14 | ubinskoye
# Processing Record 12 of Set 14 | tefe
# Processing Record 13 of Set 14 | yirol
# City yirol not found. Skipping...
# Processing Record 14 of Set 14 | west hollywood
# Processing Record 15 of Set 14 | kununurra
# Processing Record 16 of Set 14 | parola
# Processing Record 17 of Set 14 | funtua
# Processing Record 18 of Set 14 | belle fourche
# Processing Record 19 of Set 14 | honjo
# Processing Record 20 of Set 14 | tazovskiy
# Processing Record 21 of Set 14 | arvika
# Processing Record 22 of Set 14 | yunjinghong
# City yunjinghong not found. Skipping...
# Processing Record 23 of Set 14 | jasper
# Processing Record 24 of Set 14 | kopanos
# Processing Record 25 of Set 14 | srednekolymsk
# Processing Record 26 of Set 14 | taoudenni
# Processing Record 27 of Set 14 | ribeira brava
# Processing Record 28 of Set 14 | muzquiz
# City muzquiz not found. Skipping...
# Processing Record 29 of Set 14 | ballina
# Processing Record 30 of Set 14 | kita
# Processing Record 31 of Set 14 | bara
# Processing Record 32 of Set 14 | ankazobe
# Processing Record 33 of Set 14 | pak phanang
# Processing Record 34 of Set 14 | itaituba
# Processing Record 35 of Set 14 | san juan de uraba
# Processing Record 36 of Set 14 | beroroha
# Processing Record 37 of Set 14 | challans
# Processing Record 38 of Set 14 | wajima
# Processing Record 39 of Set 14 | mpanda
# Processing Record 40 of Set 14 | orange
# Processing Record 41 of Set 14 | cabra
# Processing Record 42 of Set 14 | santiago
# Processing Record 43 of Set 14 | tumpat
# Processing Record 44 of Set 14 | san andres
# Processing Record 45 of Set 14 | volosovo
# Processing Record 46 of Set 14 | plettenberg bay
# Processing Record 47 of Set 14 | eldikan
# City eldikan not found. Skipping...
# Processing Record 48 of Set 14 | minsk
# Processing Record 49 of Set 14 | nizhneyansk
# City nizhneyansk not found. Skipping...
# Processing Record 50 of Set 14 | kahului
# Processing Record 1 of Set 15 | sorong
# Processing Record 2 of Set 15 | bria
# Processing Record 3 of Set 15 | aksu
# Processing Record 4 of Set 15 | auki
# Processing Record 5 of Set 15 | ola
# Processing Record 6 of Set 15 | itacoatiara
# Processing Record 7 of Set 15 | guiren
# Processing Record 8 of Set 15 | mendahara
# City mendahara not found. Skipping...
# Processing Record 9 of Set 15 | kamenka
# Processing Record 10 of Set 15 | vadso
# Processing Record 11 of Set 15 | kyabram
# Processing Record 12 of Set 15 | necochea
# Processing Record 13 of Set 15 | khash
# Processing Record 14 of Set 15 | puerto cabezas
# Processing Record 15 of Set 15 | muzhi
# Processing Record 16 of Set 15 | udomlya
# Processing Record 17 of Set 15 | cam ranh
# Processing Record 18 of Set 15 | preobrazheniye
# Processing Record 19 of Set 15 | dalnerechensk
# Processing Record 20 of Set 15 | vreed en hoop
# City vreed en hoop not found. Skipping...
# Processing Record 21 of Set 15 | bur gabo
# City bur gabo not found. Skipping...
# Processing Record 22 of Set 15 | porto-vecchio
# Processing Record 23 of Set 15 | iberia
# Processing Record 24 of Set 15 | arlit
# Processing Record 25 of Set 15 | lephepe
# City lephepe not found. Skipping...
# Processing Record 26 of Set 15 | tete
# Processing Record 27 of Set 15 | miraflores
# Processing Record 28 of Set 15 | saint-joseph
# Processing Record 29 of Set 15 | pampa
# Processing Record 30 of Set 15 | ouesso
# Processing Record 31 of Set 15 | rocha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mana      GF   5.66  -53.78     78.76        88           8
# 1  North Bend      US  43.41 -124.22     81.00        72           1
# 2  Ogdensburg      US  44.69  -75.49     64.00        93          20
# 3      Olinda      BR  -8.01  -34.86     78.80        78          75
# 4       Upata      VE   8.01  -62.40     82.00        76          32
# 5      Albany      US  42.60  -73.97     68.00        82         100
# 6      Zhuhai      CN  22.28  113.57     86.00        84          20
# 7      Hobart      AU -42.88  147.33     57.99        58          75
# 8       Muros      ES  42.78   -9.06     57.00        93           5
# 9      Dikson      RU  73.51   80.55     48.07        83          84
#
#    Wind Speed Current Description
# 0        5.14           clear sky
# 1       25.28           clear sky
# 2        3.89          few clouds
# 3       10.29       broken clouds
# 4        1.99    scattered clouds
# 5        1.54     overcast clouds
# 6        3.36          few clouds
# 7       13.87       broken clouds
# 8        1.01           clear sky
# 9        6.82       broken clouds

# %%
# Export the City_Data into a CSV.
city_weather_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')
